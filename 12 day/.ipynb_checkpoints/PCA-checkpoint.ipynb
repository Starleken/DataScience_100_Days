# %%
import numpy as np
import pandas as pd

import sklearn
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('https://www.dropbox.com/s/9t04t1haanbdvvt/bank-data-for-pca.csv?dl=1')
df
# Out:
#        Возраст              Работа        Семейный статус  \
# 0         27.0         Самозанятый  Не женат / не замужем
# 1         30.0    Преддприниматель        Женат / замужем
# 2         39.0  Голубой воротничок        Женат / замужем
# 3         42.0            Менеджер        Женат / замужем
# 4         42.0         Самозанятый        Женат / замужем
# ...        ...                 ...                    ...
# 41171     68.0           Пенсионер           Разведен(-а)
# 41172     68.0           Пенсионер           Разведен(-а)
# 41173     74.0           Пенсионер           Разведен(-а)
# 41174     74.0           Пенсионер           Разведен(-а)
# 41175     84.0           Пенсионер           Разведен(-а)
#
#                    Образование Кредитный дефолт Ипотека Займ  \
# 0      Университетская степень              Нет     Нет  Нет
# 1      Университетская степень              Нет     Нет  Нет
# 2          Базовое (9 классов)              Нет     Нет  Нет
# 3                 Высшая школа              Нет      Да   Да
# 4           Базовое (4 класса)              Нет     Нет  Нет
# ...                        ...              ...     ...  ...
# 41171             Высшая школа              Нет      Да  Нет
# 41172             Высшая школа              Нет      Да   Да
# 41173       Базовое (4 класса)              Нет      Да  Нет
# 41174       Базовое (4 класса)              Нет      Да  Нет
# 41175       Базовое (4 класса)       Неизвестно      Да   Да
#
#                  Контакт    Месяц  День недели  Длительность  Кампания  \
# 0      Городской телефон  Октябрь            5          24.0       1.0
# 1      Городской телефон  Октябрь            5         223.0       1.0
# 2      Городской телефон  Октябрь            5         270.0       1.0
# 3      Городской телефон  Октябрь            5         103.0       1.0
# 4      Городской телефон  Октябрь            5         478.0       1.0
# ...                  ...      ...          ...           ...       ...
# 41171    Сотовый телефон  Октябрь            1         222.0       1.0
# 41172    Сотовый телефон  Октябрь            1         567.0       1.0
# 41173    Сотовый телефон  Октябрь            1         102.0       3.0
# 41174    Сотовый телефон  Октябрь            1         180.0       2.0
# 41175    Сотовый телефон  Октябрь            1         138.0       4.0
#
#        Предыдущий контакт    Доходность  Колебание уровня безработицы  \
# 0                     0.0   Отсутствует                          -0.1
# 1                     0.0   Отсутствует                          -0.1
# 2                     0.0   Отсутствует                          -0.1
# 3                     0.0   Отсутствует                          -0.1
# 4                     0.0   Отсутствует                          -0.1
# ...                   ...           ...                           ...
# 41171                 0.0   Отсутствует                          -1.1
# 41172                 1.0  Присутствует                          -1.1
# 41173                 2.0  Присутствует                          -1.1
# 41174                 0.0   Отсутствует                          -1.1
# 41175                 1.0  Присутствует                          -1.1
#
#        Индекс потребительских цен  Индекс потребительской уверенности  \
# 0                          93.798                               -40.4
# 1                          93.798                               -40.4
# 2                          93.798                               -40.4
# 3                          93.798                               -40.4
# 4                          93.798                               -40.4
# ...                           ...                                 ...
# 41171                      94.601                               -49.5
# 41172                      94.601                               -49.5
# 41173                      94.601                               -49.5
# 41174                      94.601                               -49.5
# 41175                      94.601                               -49.5
#
#        Европейская межбанковская ставка  Количество сотрудников в компании  \
# 0                                 5.045                             5195.0
# 1                                 5.045                             5195.0
# 2                                 5.045                             5195.0
# 3                                 5.045                             5195.0
# 4                                 5.045                             5195.0
# ...                                 ...                                ...
# 41171                             1.000                             4963.0
# 41172                             1.000                             4963.0
# 41173                             1.000                             4963.0
# 41174                             1.000                             4963.0
# 41175                             1.000                             4963.0
#
#          y
# 0      Нет
# 1       Да
# 2       Да
# 3       Да
# 4       Да
# ...    ...
# 41171   Да
# 41172   Да
# 41173  Нет
# 41174  Нет
# 41175  Нет
#
# [41176 rows x 20 columns]

# %%
X = df[['Возраст', 'Длительность', 'Кампания', 'День недели', 'Предыдущий контакт', 'Индекс потребительских цен', 'Европейская межбанковская ставка', 'Количество сотрудников в компании']]
y = df.iloc[:, -1]

# %%
x = StandardScaler().fit_transform(X)
pd.DataFrame(x).head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -1.249818 -0.903640 -0.565963  1.431363 -0.349551  0.384015  0.820856
# 1 -0.961926 -0.136196 -0.565963  1.431363 -0.349551  0.384015  0.820856
# 2 -0.098248  0.045060 -0.565963  1.431363 -0.349551  0.384015  0.820856
# 3  0.189644 -0.598976 -0.565963  1.431363 -0.349551  0.384015  0.820856
# 4  0.189644  0.847213 -0.565963  1.431363 -0.349551  0.384015  0.820856
#
#           7
# 0  0.389225
# 1  0.389225
# 2  0.389225
# 3  0.389225
# 4  0.389225

# %%
pca = PCA(n_components = 1)

principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1'])

principalDf.head()
# Out:
#    principal component 1
# 0              -0.946370
# 1              -0.918696
# 2              -0.907002
# 3              -0.926795
# 4              -0.878160
